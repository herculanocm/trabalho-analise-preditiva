# %% [markdown]
# # Pós Graduação em Ciência de Dados e Big Data PUC Minas Uberlândia
# ## APD - Análise preditiva
# **Aluno**: Herculano Cunha, Warla

# %% [markdown]
# ## Atividades
# 1. Obtenção dos dados;
# 2. Limpeza dos dados;
# 3. Visualização dos dados;
# 4. Modelagem e predição;
# 5. Interpretação da predição

# %% [markdown]
# ### Importação de Bibliotecas

# %%
import pandas as pd
import calendar as cal
from datetime import datetime
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
import numpy as np
from math import sqrt

# %% [markdown]
# ### Leitura de dataframes do bolsa familia

# %%
familia_df = pd.read_csv('./dados/base_amostra_familia_201712-20180411-145946.csv',encoding='utf-8',sep=';', low_memory=False)
#pessoa_df = pd.read_csv('./dados/base_amostra_pessoa_201712-20180411-145946.csv',encoding='utf-8',sep=';')

# %% [markdown]
# ### Exibição dos dataframes

# %%
familia_df
# Out:
#          id_familia  cd_ibge  estrato  classf dat_cadastramento_fam  \
# 0                 1  4124053        1       3            2013-10-31
# 1                 2  3168002        2       3            2012-09-13
# 2                 3  5002704        2       1            2017-11-22
# 3                 4  3106705        2       2            2004-08-27
# 4                 5  3154606        2       2            2006-07-08
# 5                 6  4119905        2       3            2014-09-24
# 6                 7  4206306        1       3            2014-06-02
# 7                 8  2611606        2       1            2017-10-05
# 8                 9  2512101        2       3            2002-03-13
# 9                10  1303908        2       3            2014-08-20
# 10               11  4306809        1       3            2016-02-22
# 11               12  2803203        2       3            2002-03-27
# 12               13  3550308        2       1            2013-06-04
# ...

# %% [markdown]
# ### Deleção das colunas que não serão utilizadas

# %%
del familia_df['estrato']
del familia_df['classf']
del familia_df['dat_alteracao_fam']
del familia_df['dat_atualizacao_familia']
del familia_df['cod_local_domic_fam']
del familia_df['cod_especie_domic_fam']
del familia_df['qtd_comodos_domic_fam']
del familia_df['qtd_comodos_dormitorio_fam']
del familia_df['cod_material_piso_fam']
del familia_df['cod_material_domic_fam']
del familia_df['cod_agua_canalizada_fam']
del familia_df['cod_abaste_agua_domic_fam']
del familia_df['cod_banheiro_domic_fam']
del familia_df['cod_escoa_sanitario_domic_fam']
del familia_df['cod_destino_lixo_domic_fam']
del familia_df['cod_iluminacao_domic_fam']
del familia_df['cod_calcamento_domic_fam']
del familia_df['cod_familia_indigena_fam']
del familia_df['ind_familia_quilombola_fam']
del familia_df['nom_estab_assist_saude_fam']
del familia_df['cod_eas_fam']
del familia_df['nom_centro_assist_fam']
del familia_df['cod_centro_assist_fam']
del familia_df['ind_parc_mds_fam']
del familia_df['marc_pbf']

# %% [markdown]
# ### Exibição dos valores formatados

# %%
familia_df
# Out:
#          id_familia  cd_ibge dat_cadastramento_fam vlr_renda_media_fam  \
# 0                 1  4124053            2013-10-31                 550
# 1                 2  3168002            2012-09-13                  83
# 2                 3  5002704            2017-11-22                   0
# 3                 4  3106705            2004-08-27                  50
# 4                 5  3154606            2006-07-08                 100
# 5                 6  4119905            2014-09-24                 100
# 6                 7  4206306            2014-06-02                 402
# 7                 8  2611606            2017-10-05                 273
# 8                 9  2512101            2002-03-13                 394
# 9                10  1303908            2014-08-20                 729
# 10               11  4306809            2016-02-22                1457
# 11               12  2803203            2002-03-27                 225
# ...
